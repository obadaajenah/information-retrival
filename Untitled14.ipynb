# %%
import sys
import pandas as pd
import pickle

def load_dataset(file_path):
    try:
        data = pd.read_csv(file_path, delimiter='\t', header=None, names=['pid', 'text'])
    except pd.errors.ParserError as e:
        print(f"Error reading the dataset file: {e}")
        sys.exit(1)
    return data

def read_cleaned_texts(file_path):
    try:
        with open(file_path, 'r' , encoding='utf-8') as file:
            lines = file.readlines()
            return [line.strip() for line in lines]
    except FileNotFoundError:
        print(f"The file {file_path} does not exist.")
        sys.exit(1)


def save_vectors_to_binary_file(vector, filename):
        
        with open(filename, "wb") as file:
          pickle.dump(vector, file)

def convert_csv_to_tsv(input_csv_path, output_tsv_path):
    try:
        # قراءة ملف CSV
        df = pd.read_csv(input_csv_path)
        
        # حفظ البيانات في ملف TSV
        df.to_csv(output_tsv_path, sep='\t', index=False)
        print(f"تم تحويل الملف بنجاح وحفظه في {output_tsv_path}")
    except Exception as e:
        print(f"حدث خطأ أثناء تحويل الملف: {e}")



def load_dataset2(file_path):
    try:
        data = pd.read_csv(file_path, delimiter='\t')
    except pd.errors.ParserError as e:
        print(f"Error reading the dataset file: {e}")
        sys.exit(1)
    return data

def read_csv_to_array(file_path):
    # قراءة ملف CSV باستخدام pandas
    df = pd.read_csv(file_path)
    
    # تحويل إطار البيانات إلى مصفوفة من القوائم
    data_array = df.values.tolist()
    
    return data_array


from fastapi import FastAPI, Request
import uvicorn
from sklearn.feature_extraction.text import TfidfVectorizer
from fastapi import FastAPI, Request
import uvicorn
print("2")
# كلاس لتحويل النصوص إلى متجهات
class TextIndexer:
 

 def clean_space(column1 , column2,column3,column4):
        column1 = column1.fillna('')
        column2 = column2.fillna('')
        column3= column3.fillna('')
        column4 = column4.fillna('')
        return column1,column2 ,column3 ,column4


# إعداد FastAPI


# إنشاء كائن من TextIndexer
indexer = TextIndexer()
###################    The first dataset ############################33333333



################# The secound dataset ########################


        


import requests
import pandas as pd
import sys
import numpy as np
import pickle
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import lil_matrix
print("3")

def get_documents_for_query(query, data_vector_file,  vectorizer_file, data_file):
    with open(data_vector_file, "rb") as file:
        data_vector = pickle.load(file)
    with open(vectorizer_file, "rb") as file:
        vectorizer = pickle.load(file)
    data = load_dataset(data_file)
    query_vector = vectorizer.transform([query])
    cosine_similarities = cosine_similarity(data_vector, query_vector).flatten()
   
    n = 10
    top_documents_indices = np.argsort(cosine_similarities)[-n:][::-1]
    top_documents = data.iloc[top_documents_indices]
    return top_documents , cosine_similarities[top_documents_indices]

def read_cleaned_texts(file_path):
    try:
        with open(file_path, 'r' , encoding='utf-8') as file:
            lines = file.readlines()
            return [line.strip() for line in lines]
    except FileNotFoundError:
        print(f"The file {file_path} does not exist.")
        sys.exit(1)

def load_and_combine_vectors(file_paths):
    all_vectors = []
    for file_path in file_paths:
        part_vectors = np.load(file_path)
        all_vectors.append(part_vectors)
    
    # التأكد من تطابق الأبعاد
    max_length = max(len(vec[0]) for vec in all_vectors)
    all_vectors_padded = []
    
    for vec in all_vectors:
        padded_vec = np.pad(vec, ((0, 0), (0, max_length - vec.shape[1])), 'constant')
        all_vectors_padded.append(padded_vec)
    
    combined_vectors = np.vstack(all_vectors_padded)
    return combined_vectors
    

import pickle
from sklearn.metrics.pairwise import cosine_similarity
import math
import numpy as np

def sanitize_data(data):
    if isinstance(data, float) and (math.isnan(data) or math.isinf(data)):
        return None  # يمكنك استبدالها بقيمة افتراضية إذا لزم الأمر
    return data



def extract_doc_ids(query_id, df):
    query_id = int(query_id)
    # قم بتصفية DataFrame باستخدام رقم الاستعلام وشرط relevance
    filtered_df = df[(df['query_id'] == query_id) & ((df['relevance'] == 1) | (df['relevance'] == 2))]
    
    # استخراج قيم doc_id وتحويلها إلى قائمة
    doc_ids = filtered_df['doc_id'].tolist()
    relevent =filtered_df['relevance'].tolist()
    return doc_ids , relevent





def get_documents_for_query2(query: str, data_vector_file: str, vectorizer_file: str, data_file: str):
        try:
            print("dddddddddddddddd")
            with open(data_vector_file, "rb") as file:
                data_vector = pickle.load(file)
            print("ffffffffffffffffffffff")
            with open(vectorizer_file, "rb") as file:
                vectorizer = pickle.load(file)
            print("pppppppppppppppp")
            data = load_dataset2(data_file)
            print("eeeeeeeeeeeeeeeeeeeeeeeeee")
            query_vector = vectorizer.transform([query])
            print("zzzzzzzzzzzzzzzzzzzzzzz")
            cosine_similarities = cosine_similarity(data_vector, query_vector).flatten().tolist()
            print("hhhhhhhhhhhhhhhhhhhhhhh")
            cosine_similarities = [sanitize_data(x) for x in cosine_similarities]
            print("llllllllllllllllllllllllllllllll")
            cosine_similarities = [int(x) for x in cosine_similarities]
            n = 10
            top_documents_indices = np.argsort(cosine_similarities)[-n:][::-1]
            print("ttttttttttttttttttttttttttttttttttttt")
            top_documents = data.iloc[top_documents_indices]
            print("sssssssssssssssssssssssssssssssssssssssssssssssss")

            return top_documents , cosine_similarities[top_documents_indices]
         
        except Exception as e:
            print(f"Error occurred: {e}")
            return {"error": str(e)}
            
from fastapi import FastAPI, Request
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import sys
import pandas as pd
import pickle
import json
# from save_read import load_dataset
from sklearn.metrics import precision_score, recall_score, average_precision_score
# from TextProcessing import TextProcessor, processtext
import uvicorn

class Evaluation:
 
    @staticmethod
    def calculate_precision_recall(y_true, y_pred, threshold=0.5):
        y_pred_binary = (y_pred >= threshold).astype(int)
        precision = precision_score(y_true, y_pred_binary, average='micro')
        recall = recall_score(y_true, y_pred_binary, average='micro')
        return precision, recall

    @staticmethod
    def calculate_map_score(y_true, y_pred):
        return average_precision_score(y_true, y_pred, average='micro')
    
    # def calculate_mrr(y_true):
    #      # Calculate reciprocal rank
           
    @staticmethod
    def load_queries(queries_paths):
        queries = []
        for file_path in queries_paths:
            with open(file_path, 'r', encoding='utf-8') as file:
                for line in file:
                    try:
                        query = json.loads(line.strip())
                        if 'query' in query:
                            queries.append(query)
                    except json.JSONDecodeError:
                        print(f"Skipping invalid line in {file_path}: {line}")
        return queries
    
    @staticmethod
    def process_texts(texts):
        processed_texts = []
        for text in texts:
            #print("text: " + text)
            processed_text = processtext(text)
            processed_texts.append(processed_text)
        return processed_texts
    
    def read_csv_to_array(file_path):
        # قراءة ملف CSV باستخدام pandas
        df = pd.read_csv(file_path)
        
        # تحويل إطار البيانات إلى مصفوفة من القوائم
        data_array = df.values.tolist()
        
        return data_array

    @staticmethod
    def get_documents_for_query_cli(query, tfidf_matrix, vectorizer, data):
        with open(tfidf_matrix, "rb") as file:
            tfidf_matrix = pickle.load(file)
            
        with open(vectorizer, "rb") as file:
            vectorizer = pickle.load(file)
            
        data = load_dataset2(data)
            
        query_vector = vectorizer.transform([query])
        cosine_similarities = cosine_similarity(tfidf_matrix, query_vector).flatten()
        n = 10
        top_documents_indices = cosine_similarities.argsort()[-n:][::-1]
        top_documents = data.iloc[top_documents_indices]
    
        return top_documents, cosine_similarities[top_documents_indices]

    @staticmethod
    def evaluation(queries_file, tfidf_matrix_file, vectorizer_file, data_file):
            queries = Evaluation.load_queries([queries_file])
            all_precisions = []
            all_recalls = []
            all_map_scores = []
            all_rr = []
            
            for query in queries:
                if 'query' in query:
                    processed_query = Evaluation.process_texts([query['query']])[0]
                    print(processed_query)
                    processed_query = processed_query['processed_text']
                    top_documents, cosine_similarities = get_documents_for_query(processed_query, tfidf_matrix_file, vectorizer_file, data_file)
                    
                    data = load_dataset(data_file)
                    relevance = np.zeros(len(data))
                    for pid in query.get('answer_pids', []):
                        relevance[np.where(data['pid'] == pid)[0]] = 1

                    y_true = relevance[top_documents.index]
                    y_pred = cosine_similarities

                    if y_true.sum() == 0:
                        print(f"No relevant documents for query ID: {query.get('qid', 'N/A')}")
                        # print("Documents found:", top_documents)
                        continue

                    precision, recall = Evaluation.calculate_precision_recall(y_true, y_pred)
                    all_precisions.append(precision)
                    all_recalls.append(recall)

                    map_score = Evaluation.calculate_map_score(y_true, y_pred)
                    all_map_scores.append(map_score)
                    # Calculate reciprocal rank
                    rr = 0
                    for i, rel in enumerate(y_true):
                        if rel == 1:
                            rr = 1 / (i + 1)  # Reciprocal rank
                            break
                    all_rr.append(rr)
                    print(f"Query ID: {query.get('qid', 'N/A')}, Precision: {precision}, Recall: {recall}, MAP Score: {map_score}, RR: {rr}")
                    # print(
                    #     f"Query ID: {query.get('qid', 'N/A')}, Precision: {precision}, Recall: {recall}, MAP Score: {map_score}, RR: {rr}")

        
            avg_precision = np.mean(all_precisions)
            avg_recall = np.mean(all_recalls)
            avg_map_score = np.mean(all_map_scores)
            mrr = np.mean(all_rr)
            # print(f"Average Precision: {avg_precision}, Average Recall: {avg_recall}, Average MAP Score: {avg_map_score}, MRR: {mrr}")
            # return avg_precision ,avg_recall ,avg_map_score
            print(f"Average Precision: {avg_precision}, Average Recall: {avg_recall}, Average MAP Score: {avg_map_score}, MRR: {mrr}")       

    @staticmethod
    def evaluation_clic(queries_file, tfidf_matrix_file, vectorizer_file, data_file):
            print("111111111111111")
            queries = read_csv_to_array(queries_file)
            all_precisions = []
            all_recalls = []
            all_map_scores = []
            all_rr = []
            print("22222222222")
            for query in queries:
                query = [str(item) for item in query]
                combined_query = ' '.join(query)
                id=query[0]  
                print("333333")
                top_documents, cosine_similarities = Evaluation.get_documents_for_query_cli(combined_query, tfidf_matrix_file,vectorizer_file, data_file)
                qrles=r"D:\qrels.csv"
                df = pd.read_csv(qrles)
                doc_ids , relevence = extract_doc_ids(id ,df)
                modfied_data=r"D:\modified_dataset.csv"
                data = pd.read_csv(modfied_data)
                relevance = np.zeros(len(data))
                for doc_id in doc_ids:
                        relevance[np.where(data['doc_id'] == doc_id)[0]] = 1

                y_true = relevance[top_documents.index]
                y_pred = cosine_similarities

                if y_true.sum() == 0:
                        print(f"No relevant documents for query ID: {query[0] }")
                        continue

                precision, recall =Evaluation.calculate_precision_recall(y_true, y_pred)
                all_precisions.append(precision)
                all_recalls.append(recall)

                map_score = Evaluation.calculate_map_score(y_true, y_pred)
                all_map_scores.append(map_score)
                rr = 0
                for i, rel in enumerate(y_true):
                    if rel == 1:
                        rr = 1 / (i + 1)  # Reciprocal rank
                        break
                all_rr.append(rr)

                print(f"Query ID: {query[0] }, Precision: {precision}, Recall: {recall}, MAP Score: {map_score}, RR: {rr}")

            avg_precision = np.mean(all_precisions)
            avg_recall = np.mean(all_recalls)
            avg_map_score = np.mean(all_map_scores)
            mrr = np.mean(all_rr)

            print(f"Average Precision: {avg_precision}, Average Recall: {avg_recall}, Average MAP Score: {avg_map_score}, MRR: {mrr}")


evaluation =Evaluation()
        


dataset_path = r"D:\collection.tsv"

data_vector_file= r"D:\DocumentVector.pkl"
vectorizer_file= r"D:\TfidfVector.pkl"
queries_file =r"C:\Users\USER\.ir_datasets\lotte\lotte_extracted\lotte\lifestyle\dev\qas.forum.jsonl"

evaluation.evaluation(queries_file ,data_vector_file,vectorizer_file,dataset_path )
# Out:
# 2
# 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 392
#     389 vectorizer_file= r"D:\TfidfVector.pkl"
#     390 queries_file =r"C:\Users\USER\.ir_datasets\lotte\lotte_extracted\lotte\lifestyle\dev\qas.forum.jsonl"
# --> 392 evaluation.evaluation(queries_file ,data_vector_file,vectorizer_file,dataset_path )
#
# NameError: name 'evaluation' is not defined

# %%
from fastapi import FastAPI, Request
import nltk
from nltk.tokenize import word_tokenize
import inflect
import re
from num2words import num2words
import uvicorn

class TextProcessor:
    
    def __init__(self):
        self.stemmer = nltk.PorterStemmer()
        self.lemmatizer = nltk.WordNetLemmatizer()
        self.inflect_engine = inflect.engine()

    @staticmethod
    def number_to_words(text):
        words = word_tokenize(text)
        converted_words = []
        for word in words:
            if word.isdigit():
                try:
                    if int(word) > 999999999:
                        converted_words.append("[Number Too Large]")
                    else:
                        converted_word = inflect.engine().number_to_words(word)
                        converted_words.append(converted_word)
                except Exception as e:
                    print(f"Error converting number to words: {e}")
                    continue
            else:
                converted_words.append(word)
        return ' '.join(converted_words)

    @staticmethod
    def cleaned_text(text):
        try:
            cleaned_text = re.sub(r'\\n', ' ', text)
            cleaned_text = re.sub(r'\W', ' ', cleaned_text)
            cleaned_text = re.sub(r'\s+', ' ', cleaned_text)
            return cleaned_text
        except Exception as e:
            print(f"Error cleaning text: {e}")
            raise e

    @staticmethod
    def normalization_example(text):
        return text.lower()

    @staticmethod
    def stemming_example(text):
        try:
            words = word_tokenize(text)
            stemmed_words = [nltk.PorterStemmer().stem(word) for word in words]
            return ' '.join(stemmed_words)
        except Exception as e:
            print(f"Error stemming text: {e}")
            raise e

    @staticmethod
    def lemmatization_example(text):
        try:
            words = word_tokenize(text)
            lemmatized_words = [nltk.WordNetLemmatizer().lemmatize(word) for word in words]
            return ' '.join(lemmatized_words)
        except Exception as e:
            print(f"Error lemmatizing text: {e}")
            raise e

    @staticmethod
    def remove_stopwords(text):
        try:
            stop_words = set(nltk.corpus.stopwords.words('english'))
            words = word_tokenize(text)
            filtered_words = [word for word in words if word.lower() not in stop_words]
            return ' '.join(filtered_words)
        except Exception as e:
            print(f"Error removing stopwords: {e}")
            raise e

    @staticmethod
    def remove_punctuation(text):
        try:
            return re.sub(r'[^\w\s,]', '', text)
        except Exception as e:
            print(f"Error removing punctuation: {e}")
            raise e
        
def processtext(text):
    
        processed_text = TextProcessor.cleaned_text(text)
        processed_text = TextProcessor.normalization_example(processed_text)
        processed_text = TextProcessor.stemming_example(processed_text)
        processed_text = TextProcessor.lemmatization_example(processed_text)
        processed_text = TextProcessor.remove_stopwords(processed_text)
        processed_text = TextProcessor.number_to_words(processed_text)
        processed_text = TextProcessor.remove_punctuation(processed_text)
        return {"processed_text": processed_text}
import sys
import pandas as pd
import pickle

def load_dataset(file_path):
    try:
        data = pd.read_csv(file_path, delimiter='\t', header=None, names=['pid', 'text'])
    except pd.errors.ParserError as e:
        print(f"Error reading the dataset file: {e}")
        sys.exit(1)
    return data

def read_cleaned_texts(file_path):
    try:
        with open(file_path, 'r' , encoding='utf-8') as file:
            lines = file.readlines()
            return [line.strip() for line in lines]
    except FileNotFoundError:
        print(f"The file {file_path} does not exist.")
        sys.exit(1)


def save_vectors_to_binary_file(vector, filename):
        
        with open(filename, "wb") as file:
          pickle.dump(vector, file)

def convert_csv_to_tsv(input_csv_path, output_tsv_path):
    try:
        # قراءة ملف CSV
        df = pd.read_csv(input_csv_path)
        
        # حفظ البيانات في ملف TSV
        df.to_csv(output_tsv_path, sep='\t', index=False)
        print(f"تم تحويل الملف بنجاح وحفظه في {output_tsv_path}")
    except Exception as e:
        print(f"حدث خطأ أثناء تحويل الملف: {e}")



def load_dataset2(file_path):
    try:
        data = pd.read_csv(file_path, delimiter='\t')
    except pd.errors.ParserError as e:
        print(f"Error reading the dataset file: {e}")
        sys.exit(1)
    return data

def read_csv_to_array(file_path):
    # قراءة ملف CSV باستخدام pandas
    df = pd.read_csv(file_path)
    
    # تحويل إطار البيانات إلى مصفوفة من القوائم
    data_array = df.values.tolist()
    
    return data_array


from fastapi import FastAPI, Request
import uvicorn
from sklearn.feature_extraction.text import TfidfVectorizer
from fastapi import FastAPI, Request
import uvicorn
print("2")
# كلاس لتحويل النصوص إلى متجهات
class TextIndexer:
 

 def clean_space(column1 , column2,column3,column4):
        column1 = column1.fillna('')
        column2 = column2.fillna('')
        column3= column3.fillna('')
        column4 = column4.fillna('')
        return column1,column2 ,column3 ,column4


# إعداد FastAPI


# إنشاء كائن من TextIndexer
indexer = TextIndexer()
###################    The first dataset ############################33333333



################# The secound dataset ########################


        


import requests
import pandas as pd
import sys
import numpy as np
import pickle
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import lil_matrix
print("3")

def get_documents_for_query(query, data_vector_file,  vectorizer_file, data_file):
    with open(data_vector_file, "rb") as file:
        data_vector = pickle.load(file)
    with open(vectorizer_file, "rb") as file:
        vectorizer = pickle.load(file)
    data = load_dataset(data_file)
    query_vector = vectorizer.transform([query])
    cosine_similarities = cosine_similarity(data_vector, query_vector).flatten()
   
    n = 10
    top_documents_indices = np.argsort(cosine_similarities)[-n:][::-1]
    top_documents = data.iloc[top_documents_indices]
    return top_documents , cosine_similarities[top_documents_indices]

def read_cleaned_texts(file_path):
    try:
        with open(file_path, 'r' , encoding='utf-8') as file:
            lines = file.readlines()
            return [line.strip() for line in lines]
    except FileNotFoundError:
        print(f"The file {file_path} does not exist.")
        sys.exit(1)

def load_and_combine_vectors(file_paths):
    all_vectors = []
    for file_path in file_paths:
        part_vectors = np.load(file_path)
        all_vectors.append(part_vectors)
    
    # التأكد من تطابق الأبعاد
    max_length = max(len(vec[0]) for vec in all_vectors)
    all_vectors_padded = []
    
    for vec in all_vectors:
        padded_vec = np.pad(vec, ((0, 0), (0, max_length - vec.shape[1])), 'constant')
        all_vectors_padded.append(padded_vec)
    
    combined_vectors = np.vstack(all_vectors_padded)
    return combined_vectors
    

import pickle
from sklearn.metrics.pairwise import cosine_similarity
import math
import numpy as np

def sanitize_data(data):
    if isinstance(data, float) and (math.isnan(data) or math.isinf(data)):
        return None  # يمكنك استبدالها بقيمة افتراضية إذا لزم الأمر
    return data



def extract_doc_ids(query_id, df):
    query_id = int(query_id)
    # قم بتصفية DataFrame باستخدام رقم الاستعلام وشرط relevance
    filtered_df = df[(df['query_id'] == query_id) & ((df['relevance'] == 1) | (df['relevance'] == 2))]
    
    # استخراج قيم doc_id وتحويلها إلى قائمة
    doc_ids = filtered_df['doc_id'].tolist()
    relevent =filtered_df['relevance'].tolist()
    return doc_ids , relevent





def get_documents_for_query2(query: str, data_vector_file: str, vectorizer_file: str, data_file: str):
        try:
            print("dddddddddddddddd")
            with open(data_vector_file, "rb") as file:
                data_vector = pickle.load(file)
            print("ffffffffffffffffffffff")
            with open(vectorizer_file, "rb") as file:
                vectorizer = pickle.load(file)
            print("pppppppppppppppp")
            data = load_dataset2(data_file)
            print("eeeeeeeeeeeeeeeeeeeeeeeeee")
            query_vector = vectorizer.transform([query])
            print("zzzzzzzzzzzzzzzzzzzzzzz")
            cosine_similarities = cosine_similarity(data_vector, query_vector).flatten().tolist()
            print("hhhhhhhhhhhhhhhhhhhhhhh")
            cosine_similarities = [sanitize_data(x) for x in cosine_similarities]
            print("llllllllllllllllllllllllllllllll")
            cosine_similarities = [int(x) for x in cosine_similarities]
            n = 10
            top_documents_indices = np.argsort(cosine_similarities)[-n:][::-1]
            print("ttttttttttttttttttttttttttttttttttttt")
            top_documents = data.iloc[top_documents_indices]
            print("sssssssssssssssssssssssssssssssssssssssssssssssss")

            return top_documents , cosine_similarities[top_documents_indices]
         
        except Exception as e:
            print(f"Error occurred: {e}")
            return {"error": str(e)}
            
from fastapi import FastAPI, Request
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import sys
import pandas as pd
import pickle
import json
# from save_read import load_dataset
from sklearn.metrics import precision_score, recall_score, average_precision_score
# from TextProcessing import TextProcessor, processtext
import uvicorn

class Evaluation:
 
    @staticmethod
    def calculate_precision_recall(y_true, y_pred, threshold=0.5):
        y_pred_binary = (y_pred >= threshold).astype(int)
        precision = precision_score(y_true, y_pred_binary, average='micro')
        recall = recall_score(y_true, y_pred_binary, average='micro')
        return precision, recall

    @staticmethod
    def calculate_map_score(y_true, y_pred):
        return average_precision_score(y_true, y_pred, average='micro')
    
    # def calculate_mrr(y_true):
    #      # Calculate reciprocal rank
           
    @staticmethod
    def load_queries(queries_paths):
        queries = []
        for file_path in queries_paths:
            with open(file_path, 'r', encoding='utf-8') as file:
                for line in file:
                    try:
                        query = json.loads(line.strip())
                        if 'query' in query:
                            queries.append(query)
                    except json.JSONDecodeError:
                        print(f"Skipping invalid line in {file_path}: {line}")
        return queries
    
    @staticmethod
    def process_texts(texts):
        processed_texts = []
        for text in texts:
            #print("text: " + text)
            processed_text = processtext(text)
            processed_texts.append(processed_text)
        return processed_texts
    
    def read_csv_to_array(file_path):
        # قراءة ملف CSV باستخدام pandas
        df = pd.read_csv(file_path)
        
        # تحويل إطار البيانات إلى مصفوفة من القوائم
        data_array = df.values.tolist()
        
        return data_array

    @staticmethod
    def get_documents_for_query_cli(query, tfidf_matrix, vectorizer, data):
        with open(tfidf_matrix, "rb") as file:
            tfidf_matrix = pickle.load(file)
            
        with open(vectorizer, "rb") as file:
            vectorizer = pickle.load(file)
            
        data = load_dataset2(data)
            
        query_vector = vectorizer.transform([query])
        cosine_similarities = cosine_similarity(tfidf_matrix, query_vector).flatten()
        n = 10
        top_documents_indices = cosine_similarities.argsort()[-n:][::-1]
        top_documents = data.iloc[top_documents_indices]
    
        return top_documents, cosine_similarities[top_documents_indices]

    @staticmethod
    def evaluation(queries_file, tfidf_matrix_file, vectorizer_file, data_file):
            queries = Evaluation.load_queries([queries_file])
            all_precisions = []
            all_recalls = []
            all_map_scores = []
            all_rr = []
            
            for query in queries:
                if 'query' in query:
                    processed_query = Evaluation.process_texts([query['query']])[0]
                    print(processed_query)
                    processed_query = processed_query['processed_text']
                    top_documents, cosine_similarities = get_documents_for_query(processed_query, tfidf_matrix_file, vectorizer_file, data_file)
                    
                    data = load_dataset(data_file)
                    relevance = np.zeros(len(data))
                    for pid in query.get('answer_pids', []):
                        relevance[np.where(data['pid'] == pid)[0]] = 1

                    y_true = relevance[top_documents.index]
                    y_pred = cosine_similarities

                    if y_true.sum() == 0:
                        print(f"No relevant documents for query ID: {query.get('qid', 'N/A')}")
                        # print("Documents found:", top_documents)
                        continue

                    precision, recall = Evaluation.calculate_precision_recall(y_true, y_pred)
                    all_precisions.append(precision)
                    all_recalls.append(recall)

                    map_score = Evaluation.calculate_map_score(y_true, y_pred)
                    all_map_scores.append(map_score)
                    # Calculate reciprocal rank
                    rr = 0
                    for i, rel in enumerate(y_true):
                        if rel == 1:
                            rr = 1 / (i + 1)  # Reciprocal rank
                            break
                    all_rr.append(rr)
                    print(f"Query ID: {query.get('qid', 'N/A')}, Precision: {precision}, Recall: {recall}, MAP Score: {map_score}, RR: {rr}")
                    # print(
                    #     f"Query ID: {query.get('qid', 'N/A')}, Precision: {precision}, Recall: {recall}, MAP Score: {map_score}, RR: {rr}")

        
            avg_precision = np.mean(all_precisions)
            avg_recall = np.mean(all_recalls)
            avg_map_score = np.mean(all_map_scores)
            mrr = np.mean(all_rr)
            # print(f"Average Precision: {avg_precision}, Average Recall: {avg_recall}, Average MAP Score: {avg_map_score}, MRR: {mrr}")
            # return avg_precision ,avg_recall ,avg_map_score
            print(f"Average Precision: {avg_precision}, Average Recall: {avg_recall}, Average MAP Score: {avg_map_score}, MRR: {mrr}")       

    @staticmethod
    def evaluation_clic(queries_file, tfidf_matrix_file, vectorizer_file, data_file):
            print("111111111111111")
            queries = read_csv_to_array(queries_file)
            all_precisions = []
            all_recalls = []
            all_map_scores = []
            all_rr = []
            print("22222222222")
            for query in queries:
                query = [str(item) for item in query]
                combined_query = ' '.join(query)
                id=query[0]  
                print("333333")
                top_documents, cosine_similarities = Evaluation.get_documents_for_query_cli(combined_query, tfidf_matrix_file,vectorizer_file, data_file)
                qrles=r"D:\qrels.csv"
                df = pd.read_csv(qrles)
                doc_ids , relevence = extract_doc_ids(id ,df)
                modfied_data=r"D:\modified_dataset.csv"
                data = pd.read_csv(modfied_data)
                relevance = np.zeros(len(data))
                for doc_id in doc_ids:
                        relevance[np.where(data['doc_id'] == doc_id)[0]] = 1

                y_true = relevance[top_documents.index]
                y_pred = cosine_similarities

                if y_true.sum() == 0:
                        print(f"No relevant documents for query ID: {query[0] }")
                        continue

                precision, recall =Evaluation.calculate_precision_recall(y_true, y_pred)
                all_precisions.append(precision)
                all_recalls.append(recall)

                map_score = Evaluation.calculate_map_score(y_true, y_pred)
                all_map_scores.append(map_score)
                rr = 0
                for i, rel in enumerate(y_true):
                    if rel == 1:
                        rr = 1 / (i + 1)  # Reciprocal rank
                        break
                all_rr.append(rr)

                print(f"Query ID: {query[0] }, Precision: {precision}, Recall: {recall}, MAP Score: {map_score}, RR: {rr}")

            avg_precision = np.mean(all_precisions)
            avg_recall = np.mean(all_recalls)
            avg_map_score = np.mean(all_map_scores)
            mrr = np.mean(all_rr)

            print(f"Average Precision: {avg_precision}, Average Recall: {avg_recall}, Average MAP Score: {avg_map_score}, MRR: {mrr}")


evaluation =Evaluation()
        


dataset_path = r"D:\collection.tsv"

data_vector_file= r"D:\DocumentVector.pkl"
vectorizer_file= r"D:\TfidfVector.pkl"
queries_file =r"C:\Users\USER\.ir_datasets\lotte\lotte_extracted\lotte\lifestyle\dev\qas.forum.jsonl"

evaluation.evaluation(queries_file ,data_vector_file,vectorizer_file,dataset_path )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 4
#       2 import nltk
#       3 from nltk.tokenize import word_tokenize
# ----> 4 import inflect
#       5 import re
#       6 from num2words import num2words
#
# ModuleNotFoundError: No module named 'inflect'

# %%
! pip install inflect
# Out:
# Collecting inflect
#   Using cached inflect-7.2.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: more-itertools in d:\annkonda2\lib\site-packages (from inflect) (10.1.0)
# Collecting typeguard>=4.0.1 (from inflect)
#   Downloading typeguard-4.3.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: typing-extensions in d:\annkonda2\lib\site-packages (from inflect) (4.9.0)
# Collecting typing-extensions (from inflect)
#   Downloading typing_extensions-4.12.1-py3-none-any.whl.metadata (3.0 kB)
# Using cached inflect-7.2.1-py3-none-any.whl (34 kB)
# Downloading typeguard-4.3.0-py3-none-any.whl (35 kB)
# Downloading typing_extensions-4.12.1-py3-none-any.whl (37 kB)
# Installing collected packages: typing-extensions, typeguard, inflect
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
# Successfully installed inflect-7.2.1 typeguard-4.3.0 typing-extensions-4.12.1

# %%
from fastapi import FastAPI, Request
import nltk
from nltk.tokenize import word_tokenize
import inflect
import re
from num2words import num2words
import uvicorn

class TextProcessor:
    
    def __init__(self):
        self.stemmer = nltk.PorterStemmer()
        self.lemmatizer = nltk.WordNetLemmatizer()
        self.inflect_engine = inflect.engine()

    @staticmethod
    def number_to_words(text):
        words = word_tokenize(text)
        converted_words = []
        for word in words:
            if word.isdigit():
                try:
                    if int(word) > 999999999:
                        converted_words.append("[Number Too Large]")
                    else:
                        converted_word = inflect.engine().number_to_words(word)
                        converted_words.append(converted_word)
                except Exception as e:
                    print(f"Error converting number to words: {e}")
                    continue
            else:
                converted_words.append(word)
        return ' '.join(converted_words)

    @staticmethod
    def cleaned_text(text):
        try:
            cleaned_text = re.sub(r'\\n', ' ', text)
            cleaned_text = re.sub(r'\W', ' ', cleaned_text)
            cleaned_text = re.sub(r'\s+', ' ', cleaned_text)
            return cleaned_text
        except Exception as e:
            print(f"Error cleaning text: {e}")
            raise e

    @staticmethod
    def normalization_example(text):
        return text.lower()

    @staticmethod
    def stemming_example(text):
        try:
            words = word_tokenize(text)
            stemmed_words = [nltk.PorterStemmer().stem(word) for word in words]
            return ' '.join(stemmed_words)
        except Exception as e:
            print(f"Error stemming text: {e}")
            raise e

    @staticmethod
    def lemmatization_example(text):
        try:
            words = word_tokenize(text)
            lemmatized_words = [nltk.WordNetLemmatizer().lemmatize(word) for word in words]
            return ' '.join(lemmatized_words)
        except Exception as e:
            print(f"Error lemmatizing text: {e}")
            raise e

    @staticmethod
    def remove_stopwords(text):
        try:
            stop_words = set(nltk.corpus.stopwords.words('english'))
            words = word_tokenize(text)
            filtered_words = [word for word in words if word.lower() not in stop_words]
            return ' '.join(filtered_words)
        except Exception as e:
            print(f"Error removing stopwords: {e}")
            raise e

    @staticmethod
    def remove_punctuation(text):
        try:
            return re.sub(r'[^\w\s,]', '', text)
        except Exception as e:
            print(f"Error removing punctuation: {e}")
            raise e
        
def processtext(text):
    
        processed_text = TextProcessor.cleaned_text(text)
        processed_text = TextProcessor.normalization_example(processed_text)
        processed_text = TextProcessor.stemming_example(processed_text)
        processed_text = TextProcessor.lemmatization_example(processed_text)
        processed_text = TextProcessor.remove_stopwords(processed_text)
        processed_text = TextProcessor.number_to_words(processed_text)
        processed_text = TextProcessor.remove_punctuation(processed_text)
        return {"processed_text": processed_text}
import sys
import pandas as pd
import pickle

def load_dataset(file_path):
    try:
        data = pd.read_csv(file_path, delimiter='\t', header=None, names=['pid', 'text'])
    except pd.errors.ParserError as e:
        print(f"Error reading the dataset file: {e}")
        sys.exit(1)
    return data

def read_cleaned_texts(file_path):
    try:
        with open(file_path, 'r' , encoding='utf-8') as file:
            lines = file.readlines()
            return [line.strip() for line in lines]
    except FileNotFoundError:
        print(f"The file {file_path} does not exist.")
        sys.exit(1)


def save_vectors_to_binary_file(vector, filename):
        
        with open(filename, "wb") as file:
          pickle.dump(vector, file)

def convert_csv_to_tsv(input_csv_path, output_tsv_path):
    try:
        # قراءة ملف CSV
        df = pd.read_csv(input_csv_path)
        
        # حفظ البيانات في ملف TSV
        df.to_csv(output_tsv_path, sep='\t', index=False)
        print(f"تم تحويل الملف بنجاح وحفظه في {output_tsv_path}")
    except Exception as e:
        print(f"حدث خطأ أثناء تحويل الملف: {e}")



def load_dataset2(file_path):
    try:
        data = pd.read_csv(file_path, delimiter='\t')
    except pd.errors.ParserError as e:
        print(f"Error reading the dataset file: {e}")
        sys.exit(1)
    return data

def read_csv_to_array(file_path):
    # قراءة ملف CSV باستخدام pandas
    df = pd.read_csv(file_path)
    
    # تحويل إطار البيانات إلى مصفوفة من القوائم
    data_array = df.values.tolist()
    
    return data_array


from fastapi import FastAPI, Request
import uvicorn
from sklearn.feature_extraction.text import TfidfVectorizer
from fastapi import FastAPI, Request
import uvicorn
print("2")
# كلاس لتحويل النصوص إلى متجهات
class TextIndexer:
 

 def clean_space(column1 , column2,column3,column4):
        column1 = column1.fillna('')
        column2 = column2.fillna('')
        column3= column3.fillna('')
        column4 = column4.fillna('')
        return column1,column2 ,column3 ,column4


# إعداد FastAPI


# إنشاء كائن من TextIndexer
indexer = TextIndexer()
###################    The first dataset ############################33333333



################# The secound dataset ########################


        


import requests
import pandas as pd
import sys
import numpy as np
import pickle
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import lil_matrix
print("3")

def get_documents_for_query(query, data_vector_file,  vectorizer_file, data_file):
    with open(data_vector_file, "rb") as file:
        data_vector = pickle.load(file)
    with open(vectorizer_file, "rb") as file:
        vectorizer = pickle.load(file)
    data = load_dataset(data_file)
    query_vector = vectorizer.transform([query])
    cosine_similarities = cosine_similarity(data_vector, query_vector).flatten()
   
    n = 10
    top_documents_indices = np.argsort(cosine_similarities)[-n:][::-1]
    top_documents = data.iloc[top_documents_indices]
    return top_documents , cosine_similarities[top_documents_indices]

def read_cleaned_texts(file_path):
    try:
        with open(file_path, 'r' , encoding='utf-8') as file:
            lines = file.readlines()
            return [line.strip() for line in lines]
    except FileNotFoundError:
        print(f"The file {file_path} does not exist.")
        sys.exit(1)

def load_and_combine_vectors(file_paths):
    all_vectors = []
    for file_path in file_paths:
        part_vectors = np.load(file_path)
        all_vectors.append(part_vectors)
    
    # التأكد من تطابق الأبعاد
    max_length = max(len(vec[0]) for vec in all_vectors)
    all_vectors_padded = []
    
    for vec in all_vectors:
        padded_vec = np.pad(vec, ((0, 0), (0, max_length - vec.shape[1])), 'constant')
        all_vectors_padded.append(padded_vec)
    
    combined_vectors = np.vstack(all_vectors_padded)
    return combined_vectors
    

import pickle
from sklearn.metrics.pairwise import cosine_similarity
import math
import numpy as np

def sanitize_data(data):
    if isinstance(data, float) and (math.isnan(data) or math.isinf(data)):
        return None  # يمكنك استبدالها بقيمة افتراضية إذا لزم الأمر
    return data



def extract_doc_ids(query_id, df):
    query_id = int(query_id)
    # قم بتصفية DataFrame باستخدام رقم الاستعلام وشرط relevance
    filtered_df = df[(df['query_id'] == query_id) & ((df['relevance'] == 1) | (df['relevance'] == 2))]
    
    # استخراج قيم doc_id وتحويلها إلى قائمة
    doc_ids = filtered_df['doc_id'].tolist()
    relevent =filtered_df['relevance'].tolist()
    return doc_ids , relevent





def get_documents_for_query2(query: str, data_vector_file: str, vectorizer_file: str, data_file: str):
        try:
            print("dddddddddddddddd")
            with open(data_vector_file, "rb") as file:
                data_vector = pickle.load(file)
            print("ffffffffffffffffffffff")
            with open(vectorizer_file, "rb") as file:
                vectorizer = pickle.load(file)
            print("pppppppppppppppp")
            data = load_dataset2(data_file)
            print("eeeeeeeeeeeeeeeeeeeeeeeeee")
            query_vector = vectorizer.transform([query])
            print("zzzzzzzzzzzzzzzzzzzzzzz")
            cosine_similarities = cosine_similarity(data_vector, query_vector).flatten().tolist()
            print("hhhhhhhhhhhhhhhhhhhhhhh")
            cosine_similarities = [sanitize_data(x) for x in cosine_similarities]
            print("llllllllllllllllllllllllllllllll")
            cosine_similarities = [int(x) for x in cosine_similarities]
            n = 10
            top_documents_indices = np.argsort(cosine_similarities)[-n:][::-1]
            print("ttttttttttttttttttttttttttttttttttttt")
            top_documents = data.iloc[top_documents_indices]
            print("sssssssssssssssssssssssssssssssssssssssssssssssss")

            return top_documents , cosine_similarities[top_documents_indices]
         
        except Exception as e:
            print(f"Error occurred: {e}")
            return {"error": str(e)}
            
from fastapi import FastAPI, Request
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import sys
import pandas as pd
import pickle
import json
# from save_read import load_dataset
from sklearn.metrics import precision_score, recall_score, average_precision_score
# from TextProcessing import TextProcessor, processtext
import uvicorn

class Evaluation:
 
    @staticmethod
    def calculate_precision_recall(y_true, y_pred, threshold=0.5):
        y_pred_binary = (y_pred >= threshold).astype(int)
        precision = precision_score(y_true, y_pred_binary, average='micro')
        recall = recall_score(y_true, y_pred_binary, average='micro')
        return precision, recall

    @staticmethod
    def calculate_map_score(y_true, y_pred):
        return average_precision_score(y_true, y_pred, average='micro')
    
    # def calculate_mrr(y_true):
    #      # Calculate reciprocal rank
           
    @staticmethod
    def load_queries(queries_paths):
        queries = []
        for file_path in queries_paths:
            with open(file_path, 'r', encoding='utf-8') as file:
                for line in file:
                    try:
                        query = json.loads(line.strip())
                        if 'query' in query:
                            queries.append(query)
                    except json.JSONDecodeError:
                        print(f"Skipping invalid line in {file_path}: {line}")
        return queries
    
    @staticmethod
    def process_texts(texts):
        processed_texts = []
        for text in texts:
            #print("text: " + text)
            processed_text = processtext(text)
            processed_texts.append(processed_text)
        return processed_texts
    
    def read_csv_to_array(file_path):
        # قراءة ملف CSV باستخدام pandas
        df = pd.read_csv(file_path)
        
        # تحويل إطار البيانات إلى مصفوفة من القوائم
        data_array = df.values.tolist()
        
        return data_array

    @staticmethod
    def get_documents_for_query_cli(query, tfidf_matrix, vectorizer, data):
        with open(tfidf_matrix, "rb") as file:
            tfidf_matrix = pickle.load(file)
            
        with open(vectorizer, "rb") as file:
            vectorizer = pickle.load(file)
            
        data = load_dataset2(data)
            
        query_vector = vectorizer.transform([query])
        cosine_similarities = cosine_similarity(tfidf_matrix, query_vector).flatten()
        n = 10
        top_documents_indices = cosine_similarities.argsort()[-n:][::-1]
        top_documents = data.iloc[top_documents_indices]
    
        return top_documents, cosine_similarities[top_documents_indices]

    @staticmethod
    def evaluation(queries_file, tfidf_matrix_file, vectorizer_file, data_file):
            queries = Evaluation.load_queries([queries_file])
            all_precisions = []
            all_recalls = []
            all_map_scores = []
            all_rr = []
            
            for query in queries:
                if 'query' in query:
                    processed_query = Evaluation.process_texts([query['query']])[0]
                    print(processed_query)
                    processed_query = processed_query['processed_text']
                    top_documents, cosine_similarities = get_documents_for_query(processed_query, tfidf_matrix_file, vectorizer_file, data_file)
                    
                    data = load_dataset(data_file)
                    relevance = np.zeros(len(data))
                    for pid in query.get('answer_pids', []):
                        relevance[np.where(data['pid'] == pid)[0]] = 1

                    y_true = relevance[top_documents.index]
                    y_pred = cosine_similarities

                    if y_true.sum() == 0:
                        print(f"No relevant documents for query ID: {query.get('qid', 'N/A')}")
                        # print("Documents found:", top_documents)
                        continue

                    precision, recall = Evaluation.calculate_precision_recall(y_true, y_pred)
                    all_precisions.append(precision)
                    all_recalls.append(recall)

                    map_score = Evaluation.calculate_map_score(y_true, y_pred)
                    all_map_scores.append(map_score)
                    # Calculate reciprocal rank
                    rr = 0
                    for i, rel in enumerate(y_true):
                        if rel == 1:
                            rr = 1 / (i + 1)  # Reciprocal rank
                            break
                    all_rr.append(rr)
                    print(f"Query ID: {query.get('qid', 'N/A')}, Precision: {precision}, Recall: {recall}, MAP Score: {map_score}, RR: {rr}")
                    # print(
                    #     f"Query ID: {query.get('qid', 'N/A')}, Precision: {precision}, Recall: {recall}, MAP Score: {map_score}, RR: {rr}")

        
            avg_precision = np.mean(all_precisions)
            avg_recall = np.mean(all_recalls)
            avg_map_score = np.mean(all_map_scores)
            mrr = np.mean(all_rr)
            # print(f"Average Precision: {avg_precision}, Average Recall: {avg_recall}, Average MAP Score: {avg_map_score}, MRR: {mrr}")
            # return avg_precision ,avg_recall ,avg_map_score
            print(f"Average Precision: {avg_precision}, Average Recall: {avg_recall}, Average MAP Score: {avg_map_score}, MRR: {mrr}")       

    @staticmethod
    def evaluation_clic(queries_file, tfidf_matrix_file, vectorizer_file, data_file):
            print("111111111111111")
            queries = read_csv_to_array(queries_file)
            all_precisions = []
            all_recalls = []
            all_map_scores = []
            all_rr = []
            print("22222222222")
            for query in queries:
                query = [str(item) for item in query]
                combined_query = ' '.join(query)
                id=query[0]  
                print("333333")
                top_documents, cosine_similarities = Evaluation.get_documents_for_query_cli(combined_query, tfidf_matrix_file,vectorizer_file, data_file)
                qrles=r"D:\qrels.csv"
                df = pd.read_csv(qrles)
                doc_ids , relevence = extract_doc_ids(id ,df)
                modfied_data=r"D:\modified_dataset.csv"
                data = pd.read_csv(modfied_data)
                relevance = np.zeros(len(data))
                for doc_id in doc_ids:
                        relevance[np.where(data['doc_id'] == doc_id)[0]] = 1

                y_true = relevance[top_documents.index]
                y_pred = cosine_similarities

                if y_true.sum() == 0:
                        print(f"No relevant documents for query ID: {query[0] }")
                        continue

                precision, recall =Evaluation.calculate_precision_recall(y_true, y_pred)
                all_precisions.append(precision)
                all_recalls.append(recall)

                map_score = Evaluation.calculate_map_score(y_true, y_pred)
                all_map_scores.append(map_score)
                rr = 0
                for i, rel in enumerate(y_true):
                    if rel == 1:
                        rr = 1 / (i + 1)  # Reciprocal rank
                        break
                all_rr.append(rr)

                print(f"Query ID: {query[0] }, Precision: {precision}, Recall: {recall}, MAP Score: {map_score}, RR: {rr}")

            avg_precision = np.mean(all_precisions)
            avg_recall = np.mean(all_recalls)
            avg_map_score = np.mean(all_map_scores)
            mrr = np.mean(all_rr)

            print(f"Average Precision: {avg_precision}, Average Recall: {avg_recall}, Average MAP Score: {avg_map_score}, MRR: {mrr}")


evaluation =Evaluation()
        


dataset_path = r"D:\collection.tsv"

data_vector_file= r"D:\DocumentVector.pkl"
vectorizer_file= r"D:\TfidfVector.pkl"
queries_file =r"C:\Users\USER\.ir_datasets\lotte\lotte_extracted\lotte\lifestyle\dev\qas.forum.jsonl"

evaluation.evaluation(queries_file ,data_vector_file,vectorizer_file,dataset_path )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 6
#       4 import inflect
#       5 import re
# ----> 6 from num2words import num2words
#       7 import uvicorn
#       9 class TextProcessor:
#
# ModuleNotFoundError: No module named 'num2words'

# %%
! pip install num2words
# Out:
# Collecting num2words
#   Using cached num2words-0.5.13-py3-none-any.whl.metadata (12 kB)
# Collecting docopt>=0.6.2 (from num2words)
#   Using cached docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Using cached num2words-0.5.13-py3-none-any.whl (143 kB)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13773 sha256=d657aa219034dd3c86b8bb3b028949ed56971a26f1d920ae32e8bc63bf124688
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\1a\b0\8c\4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
# Successfully built docopt
# Installing collected packages: docopt, num2words
# Successfully installed docopt-0.6.2 num2words-0.5.13

# %%
from fastapi import FastAPI, Request
import nltk
from nltk.tokenize import word_tokenize
import inflect
import re
from num2words import num2words
import uvicorn

class TextProcessor:
    
    def __init__(self):
        self.stemmer = nltk.PorterStemmer()
        self.lemmatizer = nltk.WordNetLemmatizer()
        self.inflect_engine = inflect.engine()

    @staticmethod
    def number_to_words(text):
        words = word_tokenize(text)
        converted_words = []
        for word in words:
            if word.isdigit():
                try:
                    if int(word) > 999999999:
                        converted_words.append("[Number Too Large]")
                    else:
                        converted_word = inflect.engine().number_to_words(word)
                        converted_words.append(converted_word)
                except Exception as e:
                    print(f"Error converting number to words: {e}")
                    continue
            else:
                converted_words.append(word)
        return ' '.join(converted_words)

    @staticmethod
    def cleaned_text(text):
        try:
            cleaned_text = re.sub(r'\\n', ' ', text)
            cleaned_text = re.sub(r'\W', ' ', cleaned_text)
            cleaned_text = re.sub(r'\s+', ' ', cleaned_text)
            return cleaned_text
        except Exception as e:
            print(f"Error cleaning text: {e}")
            raise e

    @staticmethod
    def normalization_example(text):
        return text.lower()

    @staticmethod
    def stemming_example(text):
        try:
            words = word_tokenize(text)
            stemmed_words = [nltk.PorterStemmer().stem(word) for word in words]
            return ' '.join(stemmed_words)
        except Exception as e:
            print(f"Error stemming text: {e}")
            raise e

    @staticmethod
    def lemmatization_example(text):
        try:
            words = word_tokenize(text)
            lemmatized_words = [nltk.WordNetLemmatizer().lemmatize(word) for word in words]
            return ' '.join(lemmatized_words)
        except Exception as e:
            print(f"Error lemmatizing text: {e}")
            raise e

    @staticmethod
    def remove_stopwords(text):
        try:
            stop_words = set(nltk.corpus.stopwords.words('english'))
            words = word_tokenize(text)
            filtered_words = [word for word in words if word.lower() not in stop_words]
            return ' '.join(filtered_words)
        except Exception as e:
            print(f"Error removing stopwords: {e}")
            raise e

    @staticmethod
    def remove_punctuation(text):
        try:
            return re.sub(r'[^\w\s,]', '', text)
        except Exception as e:
            print(f"Error removing punctuation: {e}")
            raise e
        
def processtext(text):
    
        processed_text = TextProcessor.cleaned_text(text)
        processed_text = TextProcessor.normalization_example(processed_text)
        processed_text = TextProcessor.stemming_example(processed_text)
        processed_text = TextProcessor.lemmatization_example(processed_text)
        processed_text = TextProcessor.remove_stopwords(processed_text)
        processed_text = TextProcessor.number_to_words(processed_text)
        processed_text = TextProcessor.remove_punctuation(processed_text)
        return {"processed_text": processed_text}
import sys
import pandas as pd
import pickle

def load_dataset(file_path):
    try:
        data = pd.read_csv(file_path, delimiter='\t', header=None, names=['pid', 'text'])
    except pd.errors.ParserError as e:
        print(f"Error reading the dataset file: {e}")
        sys.exit(1)
    return data

def read_cleaned_texts(file_path):
    try:
        with open(file_path, 'r' , encoding='utf-8') as file:
            lines = file.readlines()
            return [line.strip() for line in lines]
    except FileNotFoundError:
        print(f"The file {file_path} does not exist.")
        sys.exit(1)


def save_vectors_to_binary_file(vector, filename):
        
        with open(filename, "wb") as file:
          pickle.dump(vector, file)

def convert_csv_to_tsv(input_csv_path, output_tsv_path):
    try:
        # قراءة ملف CSV
        df = pd.read_csv(input_csv_path)
        
        # حفظ البيانات في ملف TSV
        df.to_csv(output_tsv_path, sep='\t', index=False)
        print(f"تم تحويل الملف بنجاح وحفظه في {output_tsv_path}")
    except Exception as e:
        print(f"حدث خطأ أثناء تحويل الملف: {e}")



def load_dataset2(file_path):
    try:
        data = pd.read_csv(file_path, delimiter='\t')
    except pd.errors.ParserError as e:
        print(f"Error reading the dataset file: {e}")
        sys.exit(1)
    return data

def read_csv_to_array(file_path):
    # قراءة ملف CSV باستخدام pandas
    df = pd.read_csv(file_path)
    
    # تحويل إطار البيانات إلى مصفوفة من القوائم
    data_array = df.values.tolist()
    
    return data_array


from fastapi import FastAPI, Request
import uvicorn
from sklearn.feature_extraction.text import TfidfVectorizer
from fastapi import FastAPI, Request
import uvicorn
print("2")
# كلاس لتحويل النصوص إلى متجهات
class TextIndexer:
 

 def clean_space(column1 , column2,column3,column4):
        column1 = column1.fillna('')
        column2 = column2.fillna('')
        column3= column3.fillna('')
        column4 = column4.fillna('')
        return column1,column2 ,column3 ,column4


# إعداد FastAPI


# إنشاء كائن من TextIndexer
indexer = TextIndexer()
###################    The first dataset ############################33333333



################# The secound dataset ########################


        


import requests
import pandas as pd
import sys
import numpy as np
import pickle
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import lil_matrix
print("3")

def get_documents_for_query(query, data_vector_file,  vectorizer_file, data_file):
    with open(data_vector_file, "rb") as file:
        data_vector = pickle.load(file)
    with open(vectorizer_file, "rb") as file:
        vectorizer = pickle.load(file)
    data = load_dataset(data_file)
    query_vector = vectorizer.transform([query])
    cosine_similarities = cosine_similarity(data_vector, query_vector).flatten()
   
    n = 10
    top_documents_indices = np.argsort(cosine_similarities)[-n:][::-1]
    top_documents = data.iloc[top_documents_indices]
    return top_documents , cosine_similarities[top_documents_indices]

def read_cleaned_texts(file_path):
    try:
        with open(file_path, 'r' , encoding='utf-8') as file:
            lines = file.readlines()
            return [line.strip() for line in lines]
    except FileNotFoundError:
        print(f"The file {file_path} does not exist.")
        sys.exit(1)

def load_and_combine_vectors(file_paths):
    all_vectors = []
    for file_path in file_paths:
        part_vectors = np.load(file_path)
        all_vectors.append(part_vectors)
    
    # التأكد من تطابق الأبعاد
    max_length = max(len(vec[0]) for vec in all_vectors)
    all_vectors_padded = []
    
    for vec in all_vectors:
        padded_vec = np.pad(vec, ((0, 0), (0, max_length - vec.shape[1])), 'constant')
        all_vectors_padded.append(padded_vec)
    
    combined_vectors = np.vstack(all_vectors_padded)
    return combined_vectors
    

import pickle
from sklearn.metrics.pairwise import cosine_similarity
import math
import numpy as np

def sanitize_data(data):
    if isinstance(data, float) and (math.isnan(data) or math.isinf(data)):
        return None  # يمكنك استبدالها بقيمة افتراضية إذا لزم الأمر
    return data



def extract_doc_ids(query_id, df):
    query_id = int(query_id)
    # قم بتصفية DataFrame باستخدام رقم الاستعلام وشرط relevance
    filtered_df = df[(df['query_id'] == query_id) & ((df['relevance'] == 1) | (df['relevance'] == 2))]
    
    # استخراج قيم doc_id وتحويلها إلى قائمة
    doc_ids = filtered_df['doc_id'].tolist()
    relevent =filtered_df['relevance'].tolist()
    return doc_ids , relevent





def get_documents_for_query2(query: str, data_vector_file: str, vectorizer_file: str, data_file: str):
        try:
            print("dddddddddddddddd")
            with open(data_vector_file, "rb") as file:
                data_vector = pickle.load(file)
            print("ffffffffffffffffffffff")
            with open(vectorizer_file, "rb") as file:
                vectorizer = pickle.load(file)
            print("pppppppppppppppp")
            data = load_dataset2(data_file)
            print("eeeeeeeeeeeeeeeeeeeeeeeeee")
            query_vector = vectorizer.transform([query])
            print("zzzzzzzzzzzzzzzzzzzzzzz")
            cosine_similarities = cosine_similarity(data_vector, query_vector).flatten().tolist()
            print("hhhhhhhhhhhhhhhhhhhhhhh")
            cosine_similarities = [sanitize_data(x) for x in cosine_similarities]
            print("llllllllllllllllllllllllllllllll")
            cosine_similarities = [int(x) for x in cosine_similarities]
            n = 10
            top_documents_indices = np.argsort(cosine_similarities)[-n:][::-1]
            print("ttttttttttttttttttttttttttttttttttttt")
            top_documents = data.iloc[top_documents_indices]
            print("sssssssssssssssssssssssssssssssssssssssssssssssss")

            return top_documents , cosine_similarities[top_documents_indices]
         
        except Exception as e:
            print(f"Error occurred: {e}")
            return {"error": str(e)}
            
from fastapi import FastAPI, Request
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import sys
import pandas as pd
import pickle
import json
# from save_read import load_dataset
from sklearn.metrics import precision_score, recall_score, average_precision_score
# from TextProcessing import TextProcessor, processtext
import uvicorn

class Evaluation:
 
    @staticmethod
    def calculate_precision_recall(y_true, y_pred, threshold=0.5):
        y_pred_binary = (y_pred >= threshold).astype(int)
        precision = precision_score(y_true, y_pred_binary, average='micro')
        recall = recall_score(y_true, y_pred_binary, average='micro')
        return precision, recall

    @staticmethod
    def calculate_map_score(y_true, y_pred):
        return average_precision_score(y_true, y_pred, average='micro')
    
    # def calculate_mrr(y_true):
    #      # Calculate reciprocal rank
           
    @staticmethod
    def load_queries(queries_paths):
        queries = []
        for file_path in queries_paths:
            with open(file_path, 'r', encoding='utf-8') as file:
                for line in file:
                    try:
                        query = json.loads(line.strip())
                        if 'query' in query:
                            queries.append(query)
                    except json.JSONDecodeError:
                        print(f"Skipping invalid line in {file_path}: {line}")
        return queries
    
    @staticmethod
    def process_texts(texts):
        processed_texts = []
        for text in texts:
            #print("text: " + text)
            processed_text = processtext(text)
            processed_texts.append(processed_text)
        return processed_texts
    
    def read_csv_to_array(file_path):
        # قراءة ملف CSV باستخدام pandas
        df = pd.read_csv(file_path)
        
        # تحويل إطار البيانات إلى مصفوفة من القوائم
        data_array = df.values.tolist()
        
        return data_array

    @staticmethod
    def get_documents_for_query_cli(query, tfidf_matrix, vectorizer, data):
        with open(tfidf_matrix, "rb") as file:
            tfidf_matrix = pickle.load(file)
            
        with open(vectorizer, "rb") as file:
            vectorizer = pickle.load(file)
            
        data = load_dataset2(data)
            
        query_vector = vectorizer.transform([query])
        cosine_similarities = cosine_similarity(tfidf_matrix, query_vector).flatten()
        n = 10
        top_documents_indices = cosine_similarities.argsort()[-n:][::-1]
        top_documents = data.iloc[top_documents_indices]
    
        return top_documents, cosine_similarities[top_documents_indices]

    @staticmethod
    def evaluation(queries_file, tfidf_matrix_file, vectorizer_file, data_file):
            queries = Evaluation.load_queries([queries_file])
            all_precisions = []
            all_recalls = []
            all_map_scores = []
            all_rr = []
            
            for query in queries:
                if 'query' in query:
                    processed_query = Evaluation.process_texts([query['query']])[0]
                    print(processed_query)
                    processed_query = processed_query['processed_text']
                    top_documents, cosine_similarities = get_documents_for_query(processed_query, tfidf_matrix_file, vectorizer_file, data_file)
                    
                    data = load_dataset(data_file)
                    relevance = np.zeros(len(data))
                    for pid in query.get('answer_pids', []):
                        relevance[np.where(data['pid'] == pid)[0]] = 1

                    y_true = relevance[top_documents.index]
                    y_pred = cosine_similarities

                    if y_true.sum() == 0:
                        print(f"No relevant documents for query ID: {query.get('qid', 'N/A')}")
                        # print("Documents found:", top_documents)
                        continue

                    precision, recall = Evaluation.calculate_precision_recall(y_true, y_pred)
                    all_precisions.append(precision)
                    all_recalls.append(recall)

                    map_score = Evaluation.calculate_map_score(y_true, y_pred)
                    all_map_scores.append(map_score)
                    # Calculate reciprocal rank
                    rr = 0
                    for i, rel in enumerate(y_true):
                        if rel == 1:
                            rr = 1 / (i + 1)  # Reciprocal rank
                            break
                    all_rr.append(rr)
                    print(f"Query ID: {query.get('qid', 'N/A')}, Precision: {precision}, Recall: {recall}, MAP Score: {map_score}, RR: {rr}")
                    # print(
                    #     f"Query ID: {query.get('qid', 'N/A')}, Precision: {precision}, Recall: {recall}, MAP Score: {map_score}, RR: {rr}")

        
            avg_precision = np.mean(all_precisions)
            avg_recall = np.mean(all_recalls)
            avg_map_score = np.mean(all_map_scores)
            mrr = np.mean(all_rr)
            # print(f"Average Precision: {avg_precision}, Average Recall: {avg_recall}, Average MAP Score: {avg_map_score}, MRR: {mrr}")
            # return avg_precision ,avg_recall ,avg_map_score
            print(f"Average Precision: {avg_precision}, Average Recall: {avg_recall}, Average MAP Score: {avg_map_score}, MRR: {mrr}")       

    @staticmethod
    def evaluation_clic(queries_file, tfidf_matrix_file, vectorizer_file, data_file):
            print("111111111111111")
            queries = read_csv_to_array(queries_file)
            all_precisions = []
            all_recalls = []
            all_map_scores = []
            all_rr = []
            print("22222222222")
            for query in queries:
                query = [str(item) for item in query]
                combined_query = ' '.join(query)
                id=query[0]  
                print("333333")
                top_documents, cosine_similarities = Evaluation.get_documents_for_query_cli(combined_query, tfidf_matrix_file,vectorizer_file, data_file)
                qrles=r"D:\qrels.csv"
                df = pd.read_csv(qrles)
                doc_ids , relevence = extract_doc_ids(id ,df)
                modfied_data=r"D:\modified_dataset.csv"
                data = pd.read_csv(modfied_data)
                relevance = np.zeros(len(data))
                for doc_id in doc_ids:
                        relevance[np.where(data['doc_id'] == doc_id)[0]] = 1

                y_true = relevance[top_documents.index]
                y_pred = cosine_similarities

                if y_true.sum() == 0:
                        print(f"No relevant documents for query ID: {query[0] }")
                        continue

                precision, recall =Evaluation.calculate_precision_recall(y_true, y_pred)
                all_precisions.append(precision)
                all_recalls.append(recall)

                map_score = Evaluation.calculate_map_score(y_true, y_pred)
                all_map_scores.append(map_score)
                rr = 0
                for i, rel in enumerate(y_true):
                    if rel == 1:
                        rr = 1 / (i + 1)  # Reciprocal rank
                        break
                all_rr.append(rr)

                print(f"Query ID: {query[0] }, Precision: {precision}, Recall: {recall}, MAP Score: {map_score}, RR: {rr}")

            avg_precision = np.mean(all_precisions)
            avg_recall = np.mean(all_recalls)
            avg_map_score = np.mean(all_map_scores)
            mrr = np.mean(all_rr)

            print(f"Average Precision: {avg_precision}, Average Recall: {avg_recall}, Average MAP Score: {avg_map_score}, MRR: {mrr}")


evaluation =Evaluation()
        


dataset_path = r"D:\collection.tsv"

data_vector_file= r"D:\DocumentVector.pkl"
vectorizer_file= r"D:\TfidfVector.pkl"
queries_file =r"C:\Users\USER\.ir_datasets\lotte\lotte_extracted\lotte\lifestyle\dev\qas.forum.jsonl"

evaluation.evaluation(queries_file ,data_vector_file,vectorizer_file,dataset_path )
# Out:
# 2
# 3
# {'processed_text': 'whi doe cat keep pat face'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 0
# {'processed_text': 'disciplin cat bad behavior'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 1, Precision: 0.6, Recall: 0.6, MAP Score: 0.2, RR: 0.2
# {'processed_text': 'fix relationship seven month old cat ive constantli abus past month'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 2, Precision: 0.8, Recall: 0.8, MAP Score: 0.3611111111111111, RR: 0.5
# {'processed_text': 'much pur much pur'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 3
# {'processed_text': 'thi street cat ask continu meow'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 4
# {'processed_text': 'cat safe eat raw meat'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 5, Precision: 0.4, Recall: 0.4, MAP Score: 0.41666666666666663, RR: 0.3333333333333333
# {'processed_text': 'win tug war'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 6, Precision: 0.8, Recall: 0.8, MAP Score: 0.8166666666666667, RR: 1.0
# {'processed_text': 'overli friendli stray cat want come hous'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 7
# {'processed_text': 'caus dog lung unknown child owner respond'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 8, Precision: 0.8, Recall: 0.8, MAP Score: 0.5833333333333333, RR: 0.5
# {'processed_text': 'thi normal first day home behavior kitten concern'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 9, Precision: 0.9, Recall: 0.9, MAP Score: 0.14285714285714285, RR: 0.14285714285714285
# {'processed_text': 'doe pur tire cat'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 10, Precision: 0.6, Recall: 0.6, MAP Score: 0.8666666666666667, RR: 1.0
# {'processed_text': 'apologis cat'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 11
# {'processed_text': 'blink slowli cat way tell love'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 12, Precision: 0.7, Recall: 0.7, MAP Score: 0.3666666666666667, RR: 0.3333333333333333
# {'processed_text': 'give cat pill'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 13, Precision: 0.3, Recall: 0.3, MAP Score: 0.6111111111111112, RR: 1.0
# {'processed_text': 'introduc aggress dog canin'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 14
# {'processed_text': 'cat eat drink anyth death fellow cat'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 15
# {'processed_text': 'whi doe cat put toy shoe'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 16
# {'processed_text': 'renam dog get shelter'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 17
# {'processed_text': 'find dog test drive'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 18
# {'processed_text': 'feed kitten onli week old mother die'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 19
# {'processed_text': 'whi cat lick plastic bag ani harm'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 20, Precision: 0.8, Recall: 0.8, MAP Score: 0.39285714285714285, RR: 0.5
# {'processed_text': 'cat tip bed side lamp dure night'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 21, Precision: 1.0, Recall: 1.0, MAP Score: 1.0, RR: 1.0
# {'processed_text': 'ok pick adult cat scruff neck'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 22, Precision: 0.6, Recall: 0.6, MAP Score: 0.7875, RR: 1.0
# {'processed_text': 'get cat wear tuxedo sever hour'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 23, Precision: 0.8, Recall: 0.8, MAP Score: 1.0, RR: 1.0
# {'processed_text': 'cat get angri scare stand'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 24, Precision: 0.8, Recall: 0.8, MAP Score: 0.125, RR: 0.125
# {'processed_text': 'prevent dog bark constantli home'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 25
# {'processed_text': 'whi dog eat grass'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 26, Precision: 0.4, Recall: 0.4, MAP Score: 1.0, RR: 1.0
# {'processed_text': 'dog get sick human ill'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 27
# {'processed_text': 'cat meow wet food morn despit dri food avail'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 28, Precision: 0.1, Recall: 0.1, MAP Score: 1.0, RR: 1.0
# {'processed_text': 'put cat carrier'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 29, Precision: 0.4, Recall: 0.4, MAP Score: 0.775, RR: 1.0
# {'processed_text': 'help obes cat lose weight'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 30
# {'processed_text': 'long cat memori'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 31, Precision: 0.7, Recall: 0.7, MAP Score: 1.0, RR: 1.0
# {'processed_text': 'gain back dog trust accident kick'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 32
# {'processed_text': 'feed cat whenev want'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 33
# {'processed_text': 'cat demand lot attent'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 34
# {'processed_text': 'declaw viabl option cat'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 35, Precision: 0.7, Recall: 0.7, MAP Score: 0.8166666666666667, RR: 1.0
# {'processed_text': 'doe neuter ani neg effect health dog'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 36, Precision: 0.8, Recall: 0.8, MAP Score: 0.2, RR: 0.2
# {'processed_text': 'safe evacu cat'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 37
# {'processed_text': 'ea dog fear loud nois'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 38, Precision: 0.9, Recall: 0.9, MAP Score: 1.0, RR: 1.0
# {'processed_text': 'stop cat eat fast throw'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 39, Precision: 0.8, Recall: 0.8, MAP Score: 0.3333333333333333, RR: 0.3333333333333333
# {'processed_text': 'let indoor cat outdoor time safe'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 40
# {'processed_text': 'keep cat christma tree'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 41, Precision: 0.7, Recall: 0.7, MAP Score: 0.7291666666666666, RR: 1.0
# {'processed_text': 'discourag cat bite'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 42, Precision: 0.4, Recall: 0.4, MAP Score: 0.14285714285714285, RR: 0.14285714285714285
# {'processed_text': 'keep cat stress free dure period constant 90db sound'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 43
# {'processed_text': 'move next bird sanctuari loo domest cat'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 44, Precision: 0.9, Recall: 0.9, MAP Score: 1.0, RR: 1.0
# {'processed_text': 'cant afford vet treatment option'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 45
# {'processed_text': 'introduc dog brand new babi'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 46, Precision: 0.7, Recall: 0.7, MAP Score: 0.5833333333333333, RR: 0.5
# {'processed_text': 'dri food better pet teeth'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 47
# {'processed_text': 'stop dog scoot drag butt'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 48
# {'processed_text': 'whi doe cat bring toy'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 49
# {'processed_text': 'cat seem dislik idea morn walk continu'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 50, Precision: 0.9, Recall: 0.9, MAP Score: 0.25, RR: 0.25
# {'processed_text': 'make babi wild rabbit pet'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 51, Precision: 0.2, Recall: 0.2, MAP Score: 0.19642857142857142, RR: 0.14285714285714285
# {'processed_text': 'okay feed cat tuna'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 52, Precision: 0.4, Recall: 0.4, MAP Score: 0.7321428571428572, RR: 1.0
# {'processed_text': 'happen cat drink coffe'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 53
# {'processed_text': 'measur weight cat'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 54, Precision: 0.1, Recall: 0.1, MAP Score: 1.0, RR: 1.0
# {'processed_text': 'activ wildlif outsid window good bad cat psycholog'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 55
# {'processed_text': 'recommend introduc kitten adult cat'}
# ...
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 2057, Precision: 0.9, Recall: 0.9, MAP Score: 0.2, RR: 0.2
# {'processed_text': 'differ clincher tubular tire'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 2058, Precision: 0.3, Recall: 0.3, MAP Score: 0.24206349206349204, RR: 0.14285714285714285
# {'processed_text': 'commut carri offic cloth doesnt get crush'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 2059, Precision: 0.9, Recall: 0.9, MAP Score: 1.0, RR: 1.0
# {'processed_text': 'use clean chain cog'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 2060
# {'processed_text': 'safest way turn left right side bike lane'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 2061, Precision: 0.2, Recall: 0.2, MAP Score: 0.1736111111111111, RR: 0.125
# {'processed_text': 'keep pant trouser get caught gear'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 2062, Precision: 0.8, Recall: 0.8, MAP Score: 0.25, RR: 0.25
# {'processed_text': 'differ tire fill co₂ v air'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 2063
# {'processed_text': 'bad road salt bike'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 2064
# {'processed_text': 'least worn tyre front back'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 2065
# {'processed_text': 'foam tube top bmx frame'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 2066, Precision: 0.7, Recall: 0.7, MAP Score: 0.30952380952380953, RR: 0.3333333333333333
# {'processed_text': 'bike equip long daili urban commut'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 2067
# {'processed_text': 'get downhil phobia'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Query ID: 2068, Precision: 0.9, Recall: 0.9, MAP Score: 0.16666666666666666, RR: 0.16666666666666666
# {'processed_text': 'polit way ride dark'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 2069
# {'processed_text': 'doe draft caus resist lead rider'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 2070
# {'processed_text': 'whi need air fill tire'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 2071
# {'processed_text': 'whi shouldnt care model make year bicycl'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 2072
# {'processed_text': 'give away light cyclist without light'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 2073
# {'processed_text': 'convert mtb road bike'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 2074
# {'processed_text': 'direct pull v brake v center pull cantilev pro con'}
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\annkonda2\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# No relevant documents for query ID: 2075
# Average Precision: 0.6628245067497405, Average Recall: 0.6628245067497405, Average MAP Score: 0.5182591476073527, MRR: 0.5697188844385106
